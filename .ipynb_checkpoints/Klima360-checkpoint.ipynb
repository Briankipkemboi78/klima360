# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import warnings
from urllib3.exceptions import InsecureRequestWarning

# Suppress warnings
warnings.simplefilter("ignore", InsecureRequestWarning)
warnings.simplefilter("ignore", FutureWarning)

# %%
# List of URLs
urls = [
    "https://statistics.kilimo.go.ke/en/KenyafarmingHH/",
    "https://statistics.kilimo.go.ke/en/2_2/",
    "https://statistics.kilimo.go.ke/en/1_3/",
    "https://statistics.kilimo.go.ke/en/2_3a/",
    "https://statistics.kilimo.go.ke/en/2_3c/",
    "https://statistics.kilimo.go.ke/en/1_7/"
]

# Dictionary to store DataFrames
dfs = {}

# Loop through each URL and store the DataFrames
for i, url in enumerate(urls, start=1):
    # Request the webpage content, ignoring SSL verification
    response = requests.get(url, verify=False)
    
    # Parse the HTML
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the table
    table = soup.find('table')
    
    # Convert the table to a pandas DataFrame
    df = pd.read_html(str(table))[0]
    
    # Store the DataFrame in the dictionary
    dfs[f'df_{i}'] = df

# Drop the first row (row 0) from all DataFrames in the dfs dictionary
for key in dfs:
    dfs[key] = dfs[key].drop(0).reset_index(drop=True)

# %% [markdown]
# #### Exploratory Data Analysis and Cleaning Up data

# %%
# Rename the DataFrames
rename_map = {
    'df_1': 'kenya_farming_households',
    'df_2': 'agricultural_subsector',
    'df_3': 'agriculture_main_purpose',
    'df_4': 'agriculture_crop_main_purpos',
    'df_5': 'livestock_Farming',
    'df_6': 'agriculture_size'
}

# %%
# Create new variables in the global scope for each renamed DataFrame
for old_name, new_name in rename_map.items():
    globals()[new_name] = dfs[old_name]

for key in dfs:
    # Replace '-' with 'county' and change 'County' to 'county'
    dfs[key].columns = (
        dfs[key].columns.str.replace('-', 'county', regex=False)
                         .str.replace('County', 'county', regex=False)
    )

# %%
agricultural_subsector.head()
# Out:
#        county  Farming Households  Crop Farming Households  \
# 0     Mombasa               13171                     7207
# 1       Kwale              109040                   100010
# 2      Kilifi              162648                   149324
# 3  Tana River               34989                    16716
# 4        Lamu               20254                    15195
#
#    Livestock Farming Households Aquaculture Households Fishing Households
# 0                          8225                     93               1409
# 1                         70211                    212               4452
# 2                         97900                    360               6393
# 3                         26182                    207               2136
# 4                         13144                     63               3162

# %% [markdown]
# ##### Which County has the highest % of farming Household

# %%
# Sorting the DataFrame by '% of farming Households' and selecting top 10
kenya_farming_households_sorted = kenya_farming_households.sort_values(by='% of farming Households', ascending=False).head(10)

# Plotting the filtered top 10 counties
plt.figure(figsize=(10, 6))
bars = plt.barh(kenya_farming_households_sorted['county'], kenya_farming_households_sorted['% of farming Households'], color='teal')

# Adding labels to the bars
for bar in bars:
    plt.text(
        bar.get_width(),
        bar.get_y() + bar.get_height() / 2,
        f'{bar.get_width():.0f}%',  # Formating the percentage to no decimal
        va='center'  # Center the text vertically
    )

plt.xlabel('Percentage of Farming Households')
plt.title('Top 10 Counties With the Highest % of Farming Households')
plt.gca().invert_yaxis()  # Display the largest bar at the top rather than at the bottom
# Removing the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
# Calculate Total Production
agriculture_crop_main_purpos['Total Production'] = agriculture_crop_main_purpos['Subsistence Crop Farming'] + agriculture_crop_main_purpos['Commercial Crop Production']

# Calculate averages
average_subsistence = agriculture_crop_main_purpos['Subsistence Crop Farming'].mean()
average_commercial = agriculture_crop_main_purpos['Commercial Crop Production'].mean()

# Find best performing crop type
total_subsistence = agriculture_crop_main_purpos['Subsistence Crop Farming'].sum()
total_commercial = agriculture_crop_main_purpos['Commercial Crop Production'].sum()

best_crop_type = "Subsistence Crop Farming" if total_subsistence > total_commercial else "Commercial Crop Production"

print(f"Average Subsistence Crop Farming: {average_subsistence}")
print(f"Average Commercial Crop Production: {average_commercial}")
print(f"Best performing crop type: {best_crop_type}")
# Out:
# Average Subsistence Crop Farming: 87728.74468085106
# Average Commercial Crop Production: 30388.872340425532
# Best performing crop type: Subsistence Crop Farming

# %%
# Calculate the ratio: Crop Farming Households / Farming Households
agriculture_crop_main_purpos['Crop Farming Ratio'] = agriculture_crop_main_purpos['Crop Farming Households'] / agriculture_crop_main_purpos['Farming Households']

# Sort by the ratio in descending order and select top 10 counties
top_10_counties = agriculture_crop_main_purpos[['county', 'Crop Farming Ratio']].sort_values(by='Crop Farming Ratio', ascending=False).head(10)

# %%
merged_data = agriculture_main_purpose.merge(kenya_farming_households, on='county', suffixes=('', '_households'))\
    .merge(agricultural_subsector, on='county', suffixes=('', '_subsector'))\
    .merge(agriculture_crop_main_purpos, on='county', suffixes=('', '_crop'))\
    .merge(livestock_Farming, on='county', suffixes=('', '_livestock'))\
    .merge(agriculture_size, on='county', suffixes=('', '_size'))

# %%
merged_data.head()
# Out:
#        county  Farming Households  Subsistence Farming  Commercial Production  \
# 0     Mombasa               13171                 9891                   2176
# 1       Kwale              109040                97816                   9788
# 2      Kilifi              162648               149648                  10890
# 3  Tana River               34989                29089                   5153
# 4        Lamu               20254                13614                   4947
#
#      DK   Total  Farming Households_households  Non Farming Households  \
# 0  1104  376212                          13171                  363041
# 1  1436  172767                         109040                   63727
# 2  2110  297935                         162648                  135287
# 3   747   66964                          34989                   31975
# 4  1693   34223                          20254                   13969
#
#    % of farming Households  Farming Households_subsector  \
# 0                      3.5                         13171
# 1                     63.1                        109040
# 2                     54.6                        162648
# 3                     52.3                         34989
# 4                     59.2                         20254
#
#    Crop Farming Households  Livestock Farming Households  \
# 0                     7207                          8225
# 1                   100010                         70211
# 2                   149324                         97900
# 3                    16716                         26182
# 4                    15195                         13144
#
#   Aquaculture Households Fishing Households  Crop Farming %  \
# 0                     93               1409       54.718700
# 1                    212               4452       91.718635
# 2                    360               6393       91.808076
# 3                    207               2136       47.775015
# 4                     63               3162       75.022218
#
#    Farming Households_crop  Crop Farming Households_crop  \
# 0                    13171                          7207
# 1                   109040                        100010
# 2                   162648                        149324
# 3                    34989                         16716
# 4                    20254                         15195
#
#    Subsistence Crop Farming  Commercial Crop Production  DK_crop  \
# 0                      6239                         954       14
# 1                     90652                        9278       80
# 2                    139438                        9802       84
# 3                     12207                        4494       15
# 4                     10561                        4624       10
#
#    Total Production  Crop Farming Ratio  Farming Households_livestock  \
# 0              7193            0.547187                         13171
# 1             99930            0.917186                        109040
# 2            149240            0.918081                        162648
# 3             16701            0.477750                         34989
# 4             15185            0.750222                         20254
#
#    Livestock Farming Households_livestock  Subsistence Livestock Farming  \
# 0                                    8225                           6465
# 1                                   70211                          63266
# 2                                   97900                          89873
# 3                                   26182                          23152
# 4                                   13144                           9744
#
#    Commercial Livestock Production  DK_livestock  Total_size  \
# 0                             1704            56       13171
# 1                             6798           147      109040
# 2                             7902           125      162648
# 3                             2746           284       34989
# 4                             3356            44       20254
#
#    Less than 1 Acre  1 – 1.99 Acre  2 – 4.99 Acre  5 – 9.99 Acre  \
# 0              6068           2280           2877            561
# 1             10346          18299          46609          19716
# 2             20384          46821          74081          13464
# 3              9218           6259          12821           3619
# 4              2887           2870           6573           3655
#
#    10 – 19.99 Acre  20 – 49.99 Acre  50 – 99 Acre 100county499 Acres  \
# 0              236               86            50                  -
# 1             8767             3329           722                 15
# 2             4335             1344           297                 14
# 3             1714              572           323                  9
# 4             2128              472            26                  6
#
#   500 – 999 Acre 1000+ Acre Not Stated
# 0              -          -       1013
# 1              1          -       1236
# 2              2          3       1903
# 3              1          6        447
# 4              -          1       1636

# %%
# List of columns to drop
columns_to_drop = [
    'DK Farming Households', 
    'Non Farming Households', 
    'Farming Households_subsector', 
    'Farming Households_crop', 
    'DK_crop',  
    'DK_livestock', 
    'Total_size', 
    'Not Stated',  
    '1000+ Acre',  
    '100county499 Acres', 
    '500 – 999 Acre', 
    'Livestock Farming Households_livestock', 
    'Farming Households_households',
    'Farming Households_livestock',
    'Crop Farming Households_crop',
    'DK',
    'Total',
    'Crop Farming Ratio',
]

# Dropping the specified columns
merged_data = merged_data.drop(columns=columns_to_drop, errors='ignore')

# %%
pd.set_option('display.max_columns', None)
merged_data.head()
# Out:
#        county  Farming Households  Subsistence Farming  Commercial Production  \
# 0     Mombasa               13171                 9891                   2176
# 1       Kwale              109040                97816                   9788
# 2      Kilifi              162648               149648                  10890
# 3  Tana River               34989                29089                   5153
# 4        Lamu               20254                13614                   4947
#
#    % of farming Households  Crop Farming Households  \
# 0                      3.5                     7207
# 1                     63.1                   100010
# 2                     54.6                   149324
# 3                     52.3                    16716
# 4                     59.2                    15195
#
#    Livestock Farming Households Aquaculture Households Fishing Households  \
# 0                          8225                     93               1409
# 1                         70211                    212               4452
# 2                         97900                    360               6393
# 3                         26182                    207               2136
# 4                         13144                     63               3162
#
#    Crop Farming %  Subsistence Crop Farming  Commercial Crop Production  \
# 0       54.718700                      6239                         954
# 1       91.718635                     90652                        9278
# 2       91.808076                    139438                        9802
# 3       47.775015                     12207                        4494
# 4       75.022218                     10561                        4624
#
#    Total Production  Subsistence Livestock Farming  \
# 0              7193                           6465
# 1             99930                          63266
# 2            149240                          89873
# 3             16701                          23152
# 4             15185                           9744
#
#    Commercial Livestock Production  Less than 1 Acre  1 – 1.99 Acre  \
# 0                             1704              6068           2280
# 1                             6798             10346          18299
# 2                             7902             20384          46821
# 3                             2746              9218           6259
# 4                             3356              2887           2870
#
#    2 – 4.99 Acre  5 – 9.99 Acre  10 – 19.99 Acre  20 – 49.99 Acre  \
# 0           2877            561              236               86
# 1          46609          19716             8767             3329
# 2          74081          13464             4335             1344
# 3          12821           3619             1714              572
# 4           6573           3655             2128              472
#
#    50 – 99 Acre
# 0            50
# 1           722
# 2           297
# 3           323
# 4            26

# %%
### Getting Rainfall data 
county_data = pd.read_excel('county_data.xlsx')
county_data.head()
# Out:
#             County Average Yearly Rainfall (mm)  Average Temperature (°C)  \
# 0          Baringo                          850                        24
# 1            Bomet                        1,350                        20
# 2          Bungoma                        1,500                        23
# 3            Busia                        1,500                        25
# 4  Elgeyo-Marakwet                        1,250                        20
#
#    Farm Size (ha)               Crop Types     Location  \
# 0               3  Maize, beans, livestock  Rift Valley
# 1               2        Tea, dairy, maize  Rift Valley
# 2               2  Sugarcane, maize, dairy      Western
# 3               2  Maize, cassava, fishing      Western
# 4               3   Dairy, maize, potatoes  Rift Valley
#
#                       Farming Practices
# 0       Mixed farming, agro-pastoralism
# 1  Small-scale farming, tea plantations
# 2          Crop rotation, intercropping
# 3          Subsistence farming, fishing
# 4              Mixed farming, terracing

# %%
# Convert necessary columns to numeric
# Remove commas from the 'Average Yearly Rainfall (mm)' column
county_data['Average Yearly Rainfall (mm)'] = county_data['Average Yearly Rainfall (mm)'].str.replace(',', '')

# Now convert the cleaned column to numeric
county_data['Average Yearly Rainfall (mm)'] = pd.to_numeric(county_data['Average Yearly Rainfall (mm)'], errors='coerce')

# %%
def categorize_risks(row):
    # Climate Risk
    if row['Average Yearly Rainfall (mm)'] < 1000 or row['Average Temperature (°C)'] > 24:
        climate_risk = 'High'
    else:
        climate_risk = 'Low'

    # Financial Risk
    if row['Farm Size (ha)'] < 2:
        financial_risk = 'High'
    else:
        financial_risk = 'Low'

    # Market Risk
    market_dependent_crops = ['Tea', 'Dairy', 'Fishing']  # crops with market challenges
    if any(crop in row['Crop Types'] for crop in market_dependent_crops):
        market_risk = 'High'
    else:
        market_risk = 'Low'

    return pd.Series([climate_risk, financial_risk, market_risk], index=['Climate Risk', 'Financial Risk', 'Market Risk'])

# Apply the function to your dataframe
county_data[['Climate Risk', 'Financial Risk', 'Market Risk']] = county_data.apply(categorize_risks, axis=1)

# %%
county_data.head()
# Out:
#             County  Average Yearly Rainfall (mm)  Average Temperature (°C)  \
# 0          Baringo                           850                        24
# 1            Bomet                          1350                        20
# 2          Bungoma                          1500                        23
# 3            Busia                          1500                        25
# 4  Elgeyo-Marakwet                          1250                        20
#
#    Farm Size (ha)               Crop Types     Location  \
# 0               3  Maize, beans, livestock  Rift Valley
# 1               2        Tea, dairy, maize  Rift Valley
# 2               2  Sugarcane, maize, dairy      Western
# 3               2  Maize, cassava, fishing      Western
# 4               3   Dairy, maize, potatoes  Rift Valley
#
#                       Farming Practices Climate Risk Financial Risk  \
# 0       Mixed farming, agro-pastoralism         High            Low
# 1  Small-scale farming, tea plantations          Low            Low
# 2          Crop rotation, intercropping          Low            Low
# 3          Subsistence farming, fishing         High            Low
# 4              Mixed farming, terracing          Low            Low
#
#   Market Risk
# 0         Low
# 1        High
# 2         Low
# 3         Low
# 4        High

# %%
county_data.rename(columns={'County': 'county'}, inplace=True)

# %%
# Merging the datasets on the 'County' column
final_data = pd.merge(merged_data, county_data, on='county', how='inner')

# %%
final_data
# Out:
#              county  Farming Households  Subsistence Farming  \
# 0           Mombasa               13171                 9891
# 1             Kwale              109040                97816
# 2            Kilifi              162648               149648
# 3        Tana River               34989                29089
# 4              Lamu               20254                13614
# 5      Taita-Taveta               56881                49105
# 6           Garissa               46109                40311
# 7             Wajir               61959                57551
# 8           Mandera               61583                55952
# 9          Marsabit               38811                36831
# 10           Isiolo               23996                22186
# 11             Meru              274081               163894
# 12    Tharaka-Nithi               85676                61578
# 13             Embu              130925                65856
# 14            Kitui              215003               196244
# 15         Machakos              231177               187651
# 16          Makueni              193384               157947
# 17        Nyandarua              140759               102378
# 18            Nyeri              164077                79809
# 19        Kirinyaga              139850                59341
# 20           Kiambu              213544               139885
# 21          Turkana               62469                56473
# 22       West Pokot               89569                81038
# 23          Samburu               42738                41349
# 24      Trans Nzoia              139981               113314
# 25      Uasin Gishu              141313               115676
# 26  Elgeyo-Marakwet               74709                59492
# 27            Nandi              148660                92293
# 28          Baringo              100242                85977
# 29         Laikipia               90457                78504
# 30           Nakuru              284495               228177
# 31            Narok              181080               142456
# 32          Kajiado               96177                80570
# 33          Kericho              150625                72109
# 34            Bomet              152384                92315
# 35         Kakamega              334835               303561
# 36           Vihiga              113645                96879
# 37          Bungoma              280086               224896
# 38            Busia              149675               135520
# 39            Siaya              197783               178340
# 40           Kisumu              147790               131769
# 41           Migori              172024               151860
# 42            Kisii              219479               128833
# 43          Nyamira              109790                40189
#
#     Commercial Production  % of farming Households  Crop Farming Households  \
# 0                    2176                      3.5                     7207
# 1                    9788                     63.1                   100010
# 2                   10890                     54.6                   149324
# 3                    5153                     52.3                    16716
# 4                    4947                     59.2                    15195
# 5                    7605                     60.2                    48379
# 6                    3668                     33.2                     4372
# 7                    2754                     48.8                     2461
# 8                    3511                     49.7                    15258
# 9                    1136                     50.6                     2644
# 10                   1585                     45.1                     2776
# 11                 109797                     64.7                   250462
# 12                  23996                     78.3                    79222
# 13                  64862                     71.8                   123261
# 14                  18334                     82.1                   199438
# 15                  43124                     57.9                   217054
# 16                  35168                     79.3                   180634
# 17                  38299                     79.0                   135142
# 18                  84152                     67.1                   154413
# 19                  80298                     68.7                   130573
# 18     Agroforestry, small-scale farming          Low            Low
# 19     Agroforestry, small-scale farming          Low            Low
# 20     Agroforestry, small-scale farming          Low            Low
# 21                  Pastoralism, fishing         High            Low
# 22       Agro-pastoralism, mixed farming         High            Low
# 23               Pastoralism, irrigation         High            Low
# 24          Mixed farming, crop rotation          Low            Low
# 25          Mixed farming, crop rotation          Low            Low
# 26              Mixed farming, terracing          Low            Low
# 27  Small-scale farming, tea plantations          Low            Low
# 28       Mixed farming, agro-pastoralism         High            Low
# 29       Mixed farming, agro-pastoralism         High            Low
# 30          Mixed farming, crop rotation          Low            Low
# 31       Agro-pastoralism, mixed farming          Low            Low
# 32       Agro-pastoralism, mixed farming         High            Low
# 33  Tea plantations, small-scale farming          Low            Low
# 34  Small-scale farming, tea plantations          Low            Low
# 35          Crop rotation, intercropping          Low            Low
# 36     Small-scale farming, agroforestry          Low            Low
# 37          Crop rotation, intercropping          Low            Low
# 38          Subsistence farming, fishing         High            Low
# 39          Subsistence farming, fishing         High            Low
# 40             Irrigation, crop rotation         High            Low
# 41                Crop rotation, fishing         High            Low
# 42     Small-scale farming, agroforestry          Low            Low
# 43     Small-scale farming, agroforestry          Low            Low
#
#    Market Risk
# 0          Low
# 1          Low
# 2          Low
# 3          Low
# 4          Low
# 5          Low
# 6          Low
# 7          Low
# 8          Low
# 9          Low
# 10         Low
# 11        High
# 12         Low
# 13         Low
# 14         Low
# 15         Low
# 16         Low
# 17        High
# 18         Low
# 19         Low
# 20         Low
# 21         Low
# 22         Low
# 23         Low
# 24         Low
# 25         Low
# 26        High
# 27        High
# 28         Low
# 29         Low
# 30        High
# 31         Low
# 32         Low
# 33        High
# 34        High
# 35         Low
# 36        High
# 37         Low
# 38         Low
# 39         Low
# 40         Low
# 41         Low
# 42        High
# 43        High

# %% [markdown]
# #### What is the % of crop farming in general

# %% [markdown]
# ### Crop Farming Percentage Formula
#
# $$
# \text{Crop Farming \%} = \left( \frac{\text{Crop Farming Households}}{\text{Farming Households}} \right) \times 100
# $$

# %%
# Calculate Crop Farming Percentage
final_data['Crop Farming %'] = (final_data['Crop Farming Households'] / final_data['Farming Households']) * 100

# Sort the DataFrame by 'Crop Farming %' and selecting top 10
county_data_sorted = final_data.sort_values(by='Crop Farming %', ascending=False).head(10)

# Plotting the filtered top 10 counties
plt.figure(figsize=(10, 6))
bars = plt.barh(county_data_sorted['county'], county_data_sorted['Crop Farming %'], color='teal')

# Adding labels to the bars
for bar in bars:
    plt.text(
        bar.get_width(),
        bar.get_y() + bar.get_height() / 2,
        f'{bar.get_width():.1f}%',  # Format the percentage to one decimal place
        va='center'  # Center the text vertically
    )

plt.xlabel('Crop Farming Percentage')
plt.title('Top 10 Counties With the Highest Crop Farming %')
plt.gca().invert_yaxis()  # Display the largest bar at the top

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %% [markdown]
# ### Which County has the highest % of farming Household

# %%
final_data.to_csv('merged_data.csv', index=False)
